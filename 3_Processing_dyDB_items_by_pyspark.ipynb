# %%
'''

@Author: Vighnesh Harish Bilgi
@Date: 2022-11-22
@Last Modified by: Vighnesh Harish Bilgi
@Last Modified time: 2022-11-22
@Title : Fetch and Process Tweet items from DynamoDB table using PySpark

'''
# Out:
# '\n\n@Author: Vighnesh Harish Bilgi\n@Date: 2022-11-22\n@Last Modified by: Vighnesh Harish Bilgi\n@Last Modified time: 2022-11-22\n@Title : Fetch and Process Tweet items from DynamoDB table using PySpark\n\n'

# %%
import findspark
findspark.init()

# %%
import json
import boto3
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
import os
os.environ['AWS_DEFAULT_REGION'] = 'us-east-1'
os.environ['AWS_ACCESS_KEY_ID'] = os.environ.get('test1_access_key')
os.environ['AWS_SECRET_ACCESS_KEY'] = os.environ.get('test1_secret_access_key')
KINESIS_DATA_STREAM = 'kds-twitter-sda'
TABLE_NAME = 'WorldCup2022Tweets'

# %%
spark = SparkSession.builder.master("local").appName("Reading DynamoDB items into RDD ").getOrCreate()
print(spark.sparkContext.appName)
# Out:
# Reading DynamoDB items into RDD

# %% [markdown]
# ### 1. Reading items from DynamoDB Table into a list of dictionaries

# %%
dyDB =  boto3.resource('dynamodb')   

table = dyDB.Table(TABLE_NAME)

table_details = table.scan()
table_items = table_details['Items']

list_of_dict = []
# appending all items/dictionaries from the table to a list
for item in table_items:
    # print(item)
    list_of_dict.append(item)

# %%
spark_df = spark.createDataFrame(list_of_dict)
spark_df.show(10)
# Out:
# C:\apps\spark-3.0.0-bin-hadoop2.7\python\pyspark\sql\session.py:378: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"
# +--------------------+--------------------+-------------------+--------------------+-------------------+---------------+--------------------+-----------------------+
# |    ArrivalTimestamp|        display_name|           tweet_id|          tweet_text|            user_id|      user_name|  word_count_on_text|word_occurences_on_text|
# +--------------------+--------------------+-------------------+--------------------+-------------------+---------------+--------------------+-----------------------+
# |2022-11-22 12:51:...|                Rags|1594954296491409409|@INSIGHTUK2 Even ...|1456973849082224646|      rhalharvi|19.00000000000000...|   19.00000000000000...|
# |2022-11-22 12:54:...|         Andy Newton|1594954908859596800|World Cup Betting...|           68403698| NewtsDailyLays|16.00000000000000...|   16.00000000000000...|
# |2022-11-22 12:50:...|        MODI FOREVER|1594953972326227968|RT @gnuseibeh: Qa...|          163162895| royprateek2010|24.00000000000000...|   24.00000000000000...|
# |2022-11-22 12:46:...|           GKT⚽JJK💜|1594952993954496512|RT @FahadAlkubais...|1291957477408272384|   lovelykana23|25.00000000000000...|   25.00000000000000...|
# |2022-11-22 12:41:...|Kumar Gaurav #Gla...|1594951772044668928|RT @gnuseibeh: Qa...|         1528472935|gauravkumar1508|24.00000000000000...|   24.00000000000000...|
# |2022-11-22 12:52:...|         Jo Geissler|1594954407086813184|@ThomasHitz @Virg...| 817098678037020673|    geissler_jo|19.00000000000000...|   19.00000000000000...|
# |2022-11-22 12:48:...|       manishnajkani|1594953468888113152|@Unimoni_India 🔥...|1180840929382600704| manishnajkani1|18.00000000000000...|   18.00000000000000...|
# |2022-11-22 12:50:...|                Mila|1594954051506298880|RT @INSIGHTUK2: "...|1591424514725814273|   Mila78604235|23.00000000000000...|   23.00000000000000...|
# |2022-11-22 12:44:...|              tarkam|1594952536863444993|@LauraMcAllister ...|1148352210327261185|  tarkamAtLarge|52.00000000000000...|   52.00000000000000...|
# |2022-11-22 12:44:...|     Md Nayeem Hasan|1594952340142182400|RT @BitMart_Futur...|1468416268294582278| Nayeemhasan121|22.00000000000000...|   22.00000000000000...|
# +--------------------+--------------------+-------------------+--------------------+-------------------+---------------+--------------------+-----------------------+
# only showing top 10 rows

# %%
spark_df.describe().show()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+
# |summary|    ArrivalTimestamp|        display_name|            tweet_id|          tweet_text|             user_id|    user_name|  word_count_on_text|word_occurences_on_text|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+
# |  count|                1004|                1004|                1004|                1004|                1004|         1004|                1004|                   1004|
# |   mean|                null|                null|1.594953288752600...|                null|1.082297965066966...|         null|21.49302788844621...|   21.49302788844621...|
# | stddev|                null|                null|1.034527046427790...|                null|5.975100107108737...|         null|   7.634532920648764|      7.634532920648764|
# |    min|2022-11-22 12:40:...|            # Tejesh| 1594951523317981184|#Iran players pro...| 1007121392054095872|   09_hickory|2.000000000000000000|   2.000000000000000000|
# |    max|2022-11-22 12:55:...|🧊Bancuhcrypto.me...| 1594955124069535745|🚨At the #WorldCu...|           999108734|zjiouo17qob__|60.00000000000000...|   60.00000000000000...|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+

# %%
spark_df.summary().show()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+
# |summary|    ArrivalTimestamp|        display_name|            tweet_id|          tweet_text|             user_id|    user_name|  word_count_on_text|word_occurences_on_text|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+
# |  count|                1004|                1004|                1004|                1004|                1004|         1004|                1004|                   1004|
# |   mean|                null|                null|1.594953288752600...|                null|1.082297965066966...|         null|21.49302788844621...|   21.49302788844621...|
# | stddev|                null|                null|1.034527046427790...|                null|5.975100107108737...|         null|   7.634532920648764|      7.634532920648764|
# |    min|2022-11-22 12:40:...|            # Tejesh| 1594951523317981184|#Iran players pro...| 1007121392054095872|   09_hickory|2.000000000000000000|   2.000000000000000000|
# |    25%|                null|                null|1.594952383477387...|                null|8.554253340065669...|         null|                19.0|                   19.0|
# |    50%|                null|                null|1.594953325094789...|                null|1.383094905816375...|         null|                21.0|                   21.0|
# |    75%|                null|                null|1.594954168602599...|                null|1.513399906052055...|         null|                24.0|                   24.0|
# |    max|2022-11-22 12:55:...|🧊Bancuhcrypto.me...| 1594955124069535745|🚨At the #WorldCu...|           999108734|zjiouo17qob__|60.00000000000000...|   60.00000000000000...|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------------+

# %% [markdown]
# ### 2. Data Processing

# %% [markdown]
# #### 2a. Dropping last column 'word_occurences_on_text'

# %%
# Dropping last column
spark_df = spark_df.drop("word_occurences_on_text")
spark_df.printSchema()
# Out:
# root
#  |-- ArrivalTimestamp: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- tweet_id: string (nullable = true)
#  |-- tweet_text: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- word_count_on_text: decimal(38,18) (nullable = true)

# %% [markdown]
# #### 2b. Changing data type of column 'word_count_on_text' from decimal to int

# %%
# Changing data types of 'word count on text' from decimal to integer
spark_df = spark_df.withColumn("word_count_on_text",spark_df.word_count_on_text.cast('int'))
spark_df.printSchema()
# Out:
# root
#  |-- ArrivalTimestamp: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- tweet_id: string (nullable = true)
#  |-- tweet_text: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- word_count_on_text: integer (nullable = true)

# %% [markdown]
# #### 2c.  Removing the milliseconds part of values under column 'ArrivalTimestamp'

# %%
# Removing the milliseconds part of ArrivalTimestamp
spark_df = spark_df.withColumn('Timestamp', substring('ArrivalTimestamp', 1,19))
spark_df.printSchema()
spark_df.select('ArrivalTimestamp','Timestamp').show(10, truncate = False)
# Out:
# root
#  |-- ArrivalTimestamp: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- tweet_id: string (nullable = true)
#  |-- tweet_text: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- word_count_on_text: integer (nullable = true)
#  |-- Timestamp: string (nullable = true)
#
# +--------------------------------+-------------------+
# |ArrivalTimestamp                |Timestamp          |
# +--------------------------------+-------------------+
# |2022-11-22 12:51:58.145000+05:30|2022-11-22 12:51:58|
# |2022-11-22 12:54:24.462000+05:30|2022-11-22 12:54:24|
# |2022-11-22 12:50:40.345000+05:30|2022-11-22 12:50:40|
# |2022-11-22 12:46:47.176000+05:30|2022-11-22 12:46:47|
# |2022-11-22 12:41:56.082000+05:30|2022-11-22 12:41:56|
# |2022-11-22 12:52:24.573000+05:30|2022-11-22 12:52:24|
# |2022-11-22 12:48:40.395000+05:30|2022-11-22 12:48:40|
# |2022-11-22 12:50:59.093000+05:30|2022-11-22 12:50:59|
# |2022-11-22 12:44:58.143000+05:30|2022-11-22 12:44:58|
# |2022-11-22 12:44:11.335000+05:30|2022-11-22 12:44:11|
# +--------------------------------+-------------------+
# only showing top 10 rows

# %% [markdown]
# #### 2d. Dropping ArrivalTimestamp column,
# #### reordering columns and
# #### then order DF by Timestamp and then tweet_id

# %%
# Dropping ArrivalTimestamp column, reordering columns and then orders DF by Timestamp and then tweet_id
# spark_df = spark_df.drop("ArrivalTimestamp", "Timestamp")
spark_df = spark_df.drop("ArrivalTimestamp")
spark_df = spark_df.withColumnRenamed("Timestamp","ArrivalTimestamp")
spark_df = spark_df.select("tweet_id","ArrivalTimestamp","display_name","user_name","user_id","tweet_text","word_count_on_text")
spark_df = spark_df.sort(col("ArrivalTimestamp"),col("tweet_id"))
spark_df.printSchema()
spark_df.show()
# Out:
# root
#  |-- tweet_id: string (nullable = true)
#  |-- ArrivalTimestamp: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- tweet_text: string (nullable = true)
#  |-- word_count_on_text: integer (nullable = true)
#
# +-------------------+-------------------+----------------------------------+---------------+-------------------+--------------------+------------------+
# |           tweet_id|   ArrivalTimestamp|                      display_name|      user_name|            user_id|          tweet_text|word_count_on_text|
# +-------------------+-------------------+----------------------------------+---------------+-------------------+--------------------+------------------+
# |1594951526619176961|2022-11-22 12:40:57|                           resa_ds|      leyla_677| 965136351455715328|RT @AmnestyIran: ...|                23|
# |1594951523317981184|2022-11-22 12:40:58|                              O.G.|  whatisgooding|         3451959143|I’m sorry, but #L...|                33|
# |1594951524769300480|2022-11-22 12:40:58|                      هەموو ژیناین|       zhinakan|1462890041437474817|Isalamic Republic...|                36|
# |1594951525843013633|2022-11-22 12:40:58|                   SPORTSCONTINENT|SPORTSCONTINEN2|1345500487374811137|NETHERLANDS 🇳🇱 ...|                15|
# |1594951529488060416|2022-11-22 12:40:58|                         Newbiland|      newbiland|1483936314110406656|RT @binary_x: ❓Wh...|                20|
# |1594951532398940160|2022-11-22 12:40:59|                      Rey Quraishi|        rey_qur|          358769498|Started as a “10”...|                30|
# |1594951534437187586|2022-11-22 12:40:59|                       Shahbaz Ali|  Shahbaz033432|1369619773106098176|@TopGoal_NFT Arge...|                 3|
# |1594951544495304704|2022-11-22 12:41:01|                             Billa|       Billa032|1593402442393489408|RT @RoadQatar_WC:...|                20|
# |1594951545069658117|2022-11-22 12:41:02|                        Zain Bajwa|  Zain_BajwaPTI|1505203001702686721|Weldon @qatar
# You...|                26|
# |1594951545849888768|2022-11-22 12:41:02|                           HQ VITA|         HQVita|1200810243372015617|• THREAD
#
# Argenti...|                17|
# |1594951550035955712|2022-11-22 12:41:03|                   Yiannis Mamakis|     yiannism80|          238065523|RT @TopGoal_NFT: ...|                19|
# |1594951550400712704|2022-11-22 12:41:03|                       Imen maamir|     ImenMaamir|1588642494413213696|@gate_io or $DUCK...|                32|
# |1594951552766447616|2022-11-22 12:41:03|ラテマエ@インデックス投資 時々 ...|   lattemaestro|1007121392054095872|RT @TopGoal_NFT: ...|                19|
# |1594951556658610176|2022-11-22 12:41:04|              Greatest Hits Rad...|     GHRNorfolk|           78933122|In the news with ...|                41|
# |1594951564069949441|2022-11-22 12:41:06|                      هەموو ژیناین|       zhinakan|1462890041437474817|Isalamic Republic...|                36|
# |1594951574950121474|2022-11-22 12:41:09|              🧊Bancuhcrypto.me...|   bancuhcrypto|1503408509756403715|RT @IOTASoccerTea...|                22|
# |1594951576124542976|2022-11-22 12:41:09|                      Amy Guettler|  saltedbayonet|          118870812|RT @TaylorMaydeuk...|                23|
# |1594951583913377793|2022-11-22 12:41:11|                        iChongqing|iChongqing_CIMC|1022324783428526080|Where's the fan o...|                37|
# |1594951598572437505|2022-11-22 12:41:15|                   Robert Quintero|RobQuintero9200|1560853965478080518|#Qatar2022 #World...|                14|
# |1594951601491709953|2022-11-22 12:41:15|                          Prof KKC|   KaranjaKeita|         3322895986|RT @Sea__Solitude...|                16|
# +-------------------+-------------------+----------------------------------+---------------+-------------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### 2e. Extract all hastags from a tweet,
# #### count all hastags from a tweet and
# #### Derive sentiment from a tweet

# %%
# Custom Function To return all the hashtags from a tweet text in a list

def extract_hashtags(text):
    """

    Description:
        To extract hashtags from tweet texts.
    Parameter:
        string text
    Return:
        list hashtag_records

    """
    hashtag_list = []

    # splitting the text into words
    for word in text.split():
    
        # checking the first character of every word
        if word[0] == '#':
            
            # adding the word to the hashtag_list
            hashtag_list.append(word[1:])
    
    # printing the hashtag_list
    hashtag_records = []
    print("The hashtags in \"" + text + "\" are :")
    for hashtag in hashtag_list:

        hashtag = '#'+hashtag
        print(hashtag)
        hashtag_records.append(hashtag)

    return hashtag_records

# %%
# Using comprehend AWS Service to derive sentiment from a tweet text.
comprehend = boto3.client('comprehend')

# creating a new dictionary of 3 keys 'hashtags_from_text', 'hashtags_count' and 'sentiment'
hash_list = []
hash_list_wc = []
sentiment = []
for i in spark_df.select("tweet_text").collect():
    # print(type(list(i)))
    hashtag_records = extract_hashtags(' '.join(list(i)))
    hashtag_string = ' '.join(hashtag_records)
    hash_list.append(hashtag_string)
    hash_list_wc.append(len(hashtag_string.strip().split()))
    sentiment.append(comprehend.detect_sentiment(Text=' '.join(list(i)),LanguageCode='en')['Sentiment'])

new_col = {}
new_col['hashtags_from_text'] = hash_list
new_col['hashtags_count'] = hash_list_wc
new_col['sentiment'] = sentiment

# build pandas DataFrame from spark_df
pandas_df = spark_df.toPandas() 
# build a new pandas df from new_col dict

new_col_pandas_df = pd.DataFrame(new_col)

# Join the new and old pandas df. 
new_and_old_pandas_df = new_col_pandas_df.join(pandas_df)

# convert the joined pandas DataFrame to spark DataFrame
spark_df = spark.createDataFrame(new_and_old_pandas_df)

# Order the columns of the DF accordingly
spark_df = spark_df.select("tweet_id","ArrivalTimestamp","display_name","user_name","user_id","tweet_text","word_count_on_text","hashtags_from_text","hashtags_count","sentiment")

# print schema of updated spark_df
spark_df.printSchema()
# Out:
# The hashtags in "RT @AmnestyIran: As the world's attention is turned to the #ENGIRN game, let's remember the faces of children killed by Iran's security for…" are :
# #ENGIRN
# The hashtags in "I’m sorry, but #Latto’s version of #BlickBlick sucks! 😩🤦🏽‍♂️ Although, her nor #CoiLeray wrote the #rap. 😒 #Rappers #FemaleRappers #HipHop #HipHopEd #HipHopNews #Queen #QueenRadio #WorldCup2022 #FIFAWorldCup2022 #NickiMinaj #HipHopBeats #DWTSFinale #SENNED #MillieMilkers #USAWAL https://t.co/aGM2TnlwIi" are :
# #Latto’s
# #BlickBlick
# #CoiLeray
# #rap.
# #Rappers
# #FemaleRappers
# #HipHop
# #HipHopEd
# #HipHopNews
# #Queen
# #QueenRadio
# #WorldCup2022
# #FIFAWorldCup2022
# #NickiMinaj
# #HipHopBeats
# #DWTSFinale
# #SENNED
# #MillieMilkers
# #USAWAL
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/6udev6ImAb" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "NETHERLANDS 🇳🇱
#
# SHOP EASY BALL HARD 🟢🟢🟢
#
# #netherlands #netherlands🇳🇱 #fifa #fifaworldcup #qatar2022 #worldcup #worldcup2022 https://t.co/B6WEIrdYUV" are :
# #netherlands
# #netherlands🇳🇱
# #fifa
# #fifaworldcup
# #qatar2022
# #worldcup
# #worldcup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "Started as a “10” in essence but most of the positioning was in the RW area.
#
# And what do #arsenal need? 👀
#
# Very impressive performance 🇳🇱
#
# #Gakpo #ned #WorldCup2022 https://t.co/rNPvJ47s10" are :
# #arsenal
# #Gakpo
# #ned
# #WorldCup2022
# The hashtags in "@TopGoal_NFT Argentina  win" are :
# The hashtags in "RT @RoadQatar_WC: 🔥🔥🔥$ROAD SUCCESSFUL LISTING ON PANCAKESWAP 🔥🔥🔥
# 🚀We are happy to announce that $ROAD has successfully listed on PANCAKESWA…" are :
# The hashtags in "Weldon @qatar
# You Slapped the Illuminati &amp; Freemasons the way you're featuring Islam via FIFA World Cup 2022 Keep shining ⭐👌👍👏❤️🇶🇦⚽🏆
#  #FIFAWorldCupQatar2022
# #FIFAWorldCup #Qatar2022 #WorldCup2022 #" are :
# #FIFAWorldCupQatar2022
# #FIFAWorldCup
# #Qatar2022
# #WorldCup2022
# #
# The hashtags in "• THREAD
#
# Argentina Portraits - FIFA World Cup Qatar 2022
#
# Lionel Scaloni 🇦🇷
#
# #FIFAWorldCup
# #WorldCup2022
# #FIFAWorldCupQatar2022 https://t.co/wDoek07OrZ" are :
# #FIFAWorldCup
# #WorldCup2022
# #FIFAWorldCupQatar2022
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "@gate_io or $DUCKER it ! don't miss out on this BLUECHIP memecoin !
# So much ducking protential !
# Too much coicidence or speculation !
# Transparent team with a clear vision !
# https://t.co/TwK7kxts3G" are :
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "In the news with
# @sian_roche this morning 🎙️
#
# ⚽ A Lowestoft company has supplied goal posts for the #WorldCup2022
#
# 🎄 MPs can expense food and drink at Christmas parties
#
# ⚡ Energy firms have been accused of failings
#
# LISTEN LIVE 👇
#
# https://t.co/omFR9VrD3H" are :
# #WorldCup2022
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/Z4kwAawPcX" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @IOTASoccerTeam: Drop SMR address for a chance to win free IOTASoccerTeam (IST) token airdrop!!!🔥
# Predict the result of Argentina vs Sau…" are :
# The hashtags in "RT @TaylorMaydeuk: Looking for gift ideas ?
#
# I have these personalised handmade crates available to order ♡
#
# Great for all occasions ♡
#
# htt…" are :
# The hashtags in "Where's the fan of #England?
# On November 21, team England beat team Iran 6-2 in the Group B match of the 2022 Qatar World Cup at the Khalifa International Stadium in Doha, Qatar. #WorldCup2022 #qatar2022 #sports https://t.co/BVFLEgbona" are :
# #England?
# #WorldCup2022
# #qatar2022
# #sports
# The hashtags in "#Qatar2022 #WorldCup2022
#
# #Argentina waiting on the 🐐 #Messi
#
# &amp; #Mexico Vs Poland 🇵🇱 https://t.co/qys9sRqxRH" are :
# #Qatar2022
# #WorldCup2022
# #Argentina
# #Messi
# #Mexico
# The hashtags in "RT @Sea__Solitude: @LinahAlsaafin Never forget when #IsraeliApartheid murdered 4 children playing football in Gaza.
# #WorldCup2022  #Israeli…" are :
# #IsraeliApartheid
# #WorldCup2022
# #Israeli…
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/p0BarWkcUJ" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "Win Cwallet World Cup OAT @BCGameOfficial https://t.co/4ku0iplzlt" are :
# The hashtags in "RT @gate_io: ⚽️The #WorldCup2022 is finally coming!⚽️
#
# Are you excited &amp; want to be part of it?🥳
#
# Join us to predict the #WorldCup winners…" are :
# #WorldCup2022
# #WorldCup
# The hashtags in "@BNBCHAIN @PolkastarterGG Come Let's join party #worldcup2022 ￼￼We are excited to kickstart @shibawc  ￼ Invite your friends ￼  https://t.co/Px4mtbYVQG #lunc #doge #shib #xrp #qatar2022 #worldcup2022 #btc￼ #shibaworldcup #ftx #fifaworldcup #eth Tg @shibaworldcup_ENG #fwc #whale #ShibaArmy #ftx https://t.co/okHYIUK1Nn" are :
# #worldcup2022
# #lunc
# #doge
# #shib
# #xrp
# #qatar2022
# #worldcup2022
# #btc￼
# #shibaworldcup
# #ftx
# #fifaworldcup
# #eth
# #fwc
# #whale
# #ShibaArmy
# #ftx
# The hashtags in "RT @sportsupdate33: Mexico vs Poland Live Stream Free, TV channel, start time, Team News and streams
#
# 🔴𝐋𝐢𝐯𝐞 𝐋𝐢𝐧𝐤 𝐎𝐧📺
# @Qatarworldcupar
#
# 🆚M…" are :
# The hashtags in "RT @INSIGHTUK2: "Football as a profession is Haram"
#
# Islamic preacher, Zakir Naik, who inspired some youths to join ISIS also said that #fo…" are :
# #fo…
# The hashtags in "Little money doubler for today. Should piss in ⚽️ #WorldCup2022 https://t.co/9bC7Ugl8du" are :
# #WorldCup2022
# The hashtags in "RT @hosseinbastani: After Piranshahr, it is #Javanrud's turn. After Javanrud, it will be the turn of other cities. When the world is busy w…" are :
# #Javanrud's
# The hashtags in "RT @ChinaDaily: From manufacturing, brand marketing to cultural derivatives, Chinese elements abound both on and off the field of the FIFA…" are :
# The hashtags in "RT @RedChilliesLabs: The biggest sports event is happening now: #WorldCup2022.
#
# A medium article about how our portfolio products are celeb…" are :
# #WorldCup2022.
# The hashtags in "@Helia_m00n @10KWorldCup @Johnsonweb3eth @joshua19921225 @Cassie0223 we are the champions!" are :
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/oX0hBcVbpI" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "@martleshamman @GMB Morning David,jeez,Madeley has me seething again. Slagging off NHS dentists and lying about a two tier system in the Scottish NHS.
# That story was debunked yesterday.
#
# #SackMadeley  #SunakOut  #GeneralElectionNow" are :
# #SackMadeley
# #SunakOut
# #GeneralElectionNow
# The hashtags in "The men, women and children of Saudi Arabia are all behind you 🇸🇦💚
#
# #WorldCup2022 https://t.co/zNbqLb4POl" are :
# #WorldCup2022
# The hashtags in "RT @TarekFatah: What #Qatar doesn't want the World to see | #WorldCup2022
#                         ⚽
# @JohnnyWHarris reveals the near slave-…" are :
# #Qatar
# #WorldCup2022
# The hashtags in "RT @Helia_m00n: Thanks @10KWorldCup @Johnsonweb3eth Airdrop❤️‍🔥
# I’ll give it to the community! Anyone want Brazil?⚽️
#
# To enter:
# 1. Follow…" are :
# The hashtags in "RT @ScottieTash: Lfg🚀🚀🚀
# USA 🇺🇸  vs ENGLAND 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# Should we do a #BadBears team USA 🇺🇸 GIVEAWAY tomorrow in support of team USA?
# 100 Retw…" are :
# #BadBears
# The hashtags in "RT @gate_io: ⚽️The #WorldCup2022 is finally coming!⚽️
#
# Are you excited &amp; want to be part of it?🥳
#
# Join us to predict the #WorldCup winners…" are :
# #WorldCup2022
# #WorldCup
# The hashtags in "RT @AmnestyIran: As the world's attention is turned to the #ENGIRN game, let's remember the faces of children killed by Iran's security for…" are :
# #ENGIRN
# The hashtags in "Herman Carmen #WorldCup2022 Yvonne Bentham Carey Roger #真人体育 Nicole Byron #J9娱乐  https://t.co/TJWgMbbZQg" are :
# #WorldCup2022
# #真人体育
# #J9娱乐
# The hashtags in "@gate_io @MdShahi18820711 Great Project" are :
# The hashtags in "RT @AminuMujahid3: Barca with eight players will be the base of theteam in the world cup in Qatar  🇪🇸 [Sport] #Barcelona #WorldCup2022 http…" are :
# #Barcelona
# #WorldCup2022
# The hashtags in "RT @twitkalk: @DFB_Team @DFB Today I feel #Quatar2022
# Today I feel moneysexual and morally disabled
# Today I like a bald spineless ex-redhe…" are :
# #Quatar2022
# The hashtags in "RT @gambabit: $50 #WorldCup Giveaway🕊️
#
# To Enter :
# ⚽️ Like + RT
# ⚽️ Guess the score of #Argentina vs #SaudiArabia
# ⚽️ Follow Us
#
# 1 Lucky Win…" are :
# #WorldCup
# #Argentina
# #SaudiArabia
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @LauraMcAllister: So, despite fine words from @FIFAWorldCup before event @Cymru rainbow Bucket hats confiscated at stadium, mine include…" are :
# The hashtags in "RT @Raptors: Who’s watching #FIFAWorldCup right now?
#
# Does P have the 👣 to join a team #WorldCup2022 https://t.co/YTvgt6iecY" are :
# #FIFAWorldCup
# #WorldCup2022
# The hashtags in "RT @Helia_m00n: Thanks @10KWorldCup @Johnsonweb3eth Airdrop❤️‍🔥
# I’ll give it to the community! Anyone want Brazil?⚽️
#
# To enter:
# 1. Follow…" are :
# The hashtags in "Finally it's here! Upto 50% off!
# Check out https://t.co/8wuNwhZ3tJ
#
# #BungomaHasDecided #kinoo #uhuru #matiangi #FIFAWorldCup2022 #WorldCup2022 #Iran #USAWAL #SENNED https://t.co/Jro0kwFbpt" are :
# #BungomaHasDecided
# #kinoo
# #uhuru
# #matiangi
# #FIFAWorldCup2022
# #WorldCup2022
# #Iran
# #USAWAL
# #SENNED
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "Mortimer Thoreau #WorldCup2022 Arlen Barrie Fabian May #德甲 Irma Morgan #体育下注  https://t.co/BANmewoS3T" are :
# #WorldCup2022
# #德甲
# #体育下注
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @BitKeepOS: ⚽️ #BitKeep FootBall Carnival Main Event is coming⚽️
#
# 🥳 Trading activity &amp; Community quiz 🥳
#
# 📅Nov 21 - Dec 20
# ✅Join our TG &amp;…" are :
# #BitKeep
# The hashtags in "RT @Al__Quraan: Hotels in Qatar, during the #WorldCup2022, will feature barcodes where fans can learn about Islam free from stereotypes. ht…" are :
# #WorldCup2022,
# The hashtags in "RT @gchahal: WATCH: #BNNQatar Reports
#
# Many Qataris were surprised when Japanese fans who came to watch the #WorldCup2022 #FIFAWorldCup hel…" are :
# #BNNQatar
# #WorldCup2022
# #FIFAWorldCup
# The hashtags in "RT @QudsNen: A Lebanese fan raises a Palestine flag during USA vs. Wales match yesterday 🇵🇸
# #FIFAWorldCup
# #WorldCup2022 https://t.co/tfRja…" are :
# #FIFAWorldCup
# #WorldCup2022
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "RT @BitMart_Futures: Are you getting ready? The #WorldCup2022 is kicking off! Drop your Champion prediction and win up to 100X Futures Fees…" are :
# #WorldCup2022
# The hashtags in "@TopGoal_NFT Predict Winning team, Argentina
# Predict Score, 2-1
# Predict Winning team+Score, Argentina (2) - Saudi (1)" are :
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "@18Pebbles_18 Worst WC ever" are :
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/ntpsc8QbgN" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @ChinaDaily: Water technology from China's Ningxia comes to #WorldCup2022 https://t.co/muS8JX9nCD" are :
# #WorldCup2022
# The hashtags in "@binary_x @SecondLiveReal A good project must be given positive input so that it develops and becomes even better
# @dani77315988
# @yudi10002
# @Viviadevi1" are :
# The hashtags in "@CryptoFaibik Come Let's join party #worldcup2022 ￼￼We are excited to kickstart @shibawc  ￼ Invite your friends ￼  https://t.co/Px4mtcgwIe #lunc #doge #shib #xrp #qatar2022 #worldcup2022 #btc￼ #shibaworldcup #ftx #fifaworldcup #eth Tg @shibaworldcup_ENG #fwc #whale #ShibaArmy #ftx https://t.co/67k8bCIcln" are :
# #worldcup2022
# #lunc
# #doge
# #shib
# #xrp
# #qatar2022
# #worldcup2022
# #btc￼
# #shibaworldcup
# #ftx
# #fifaworldcup
# #eth
# #fwc
# #whale
# #ShibaArmy
# #ftx
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @BitMart_Futures: Are you getting ready? The #WorldCup2022 is kicking off! Drop your Champion prediction and win up to 100X Futures Fees…" are :
# #WorldCup2022
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "RT @BitMart_Futures: Are you getting ready? The #WorldCup2022 is kicking off! Drop your Champion prediction and win up to 100X Futures Fees…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "@financ1eelvrij 🎴Memecard 🎴
# 💗NFT Marketplace💗
# ☑️Presale live :
# https://t.co/x2drxaD8iL
#
# https://t.co/B1NXsqDh6O
#
# 👑The first NFT marketplace focusing on meme coins👑
# ❤️Unique membership mechanism❤️
# 👍 KYC and Audited 👍
# 🦎Pre listed on COINGECKO!🦎
#
# 📱 https://t.co/djuDZ6XEEy" are :
# The hashtags in "RT @ToshibaTVGlobal: Dedicated to ideal leisure, Toshiba TV’s Mid-field Voice Control cues your voice command from anywhere in the room.…" are :
# The hashtags in "Weldon @qatar
# You Slapped the Illuminati &amp; Freemasons the way you're featuring Islam via FIFA World Cup 2022 Keep shining ⭐👌👍👏❤️🇶🇦⚽🏆
#  #FIFAWorldCupQatar2022
# #FIFAWorldCup    #Qatar2022    #WorldCup2022
# #FIFAWorldCupQatar2022" are :
# #FIFAWorldCupQatar2022
# #FIFAWorldCup
# #Qatar2022
# #WorldCup2022
# #FIFAWorldCupQatar2022
# The hashtags in "RT @_sportspredict: We are so hyped to watch today's matches in #FIFAWorldCup 🔥🏆
#
# #ARG vs #SAU🇸🇦
# #DEN vs #TUN
# #MEX vs #POL
# #FRA vs #AUS…" are :
# #FIFAWorldCup
# #ARG
# #SAU🇸🇦
# #DEN
# #TUN
# #MEX
# #POL
# #FRA
# #AUS…
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/cGKgFfEgDC" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @GalaxyFMUg: Who’s Winning The #WorldCup2022?
#
# #ZzinaPolls" are :
# #WorldCup2022?
# #ZzinaPolls
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "If you want to know what Qatar getting the #FIFAWorldCup was a bad idea and how awful FIFA is you should watch FIFA UNCOVERED on @netflix.  #WorldCup #WorldCup2022 #FIFAWorldCup2022 https://t.co/nck2PYlg4W" are :
# #FIFAWorldCup
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @twitkalk: @DFB_Team @DFB Today I feel #Quatar2022
# Today I feel moneysexual and morally disabled
# Today I like a bald spineless ex-redhe…" are :
# #Quatar2022
# The hashtags in "@TopGoal_NFT Argentina win.     Argentina 3:0 Saudi" are :
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "RT @BeyondTrust: Cyber criminals have World Cup #Qatar2022 in their sights. Volumes of malicious cyber activity around the upcoming FIFA Wo…" are :
# #Qatar2022
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "@Unimoni_India Denmark
#
# #contestalert #contest #contestalerindia #contestindia #worldcup #worldcup2022 #football #prediction #worldcupprediction #winner
# @Unimoni_India
# Tagging
# @kittupari31
# @khambaty_rehana
# @p_pinky777" are :
# #contestalert
# #contest
# #contestalerindia
# #contestindia
# #worldcup
# #worldcup2022
# #football
# #prediction
# #worldcupprediction
# #winner
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/QRAcHfiPoF" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @Unimoni_India: 𝗣𝗿𝗲𝗱𝗶𝗰𝘁 𝗮𝗻𝗱 𝘄𝗶𝗻 𝗧𝗼𝗱𝗮𝘆'𝘀 𝗙𝗶𝗳𝗮 𝗪𝗼𝗿𝗹𝗱 𝗖𝘂𝗽 𝗠𝗮𝘁𝗰𝗵. 𝗗𝗲𝗻𝗺𝗮𝗿𝗸 𝘃𝘀 𝗧𝘂𝗻𝗶𝘀𝗶𝗮
# #contestalert #contest #contestalerindia #contestindia…" are :
# #contestalert
# #contest
# #contestalerindia
# #contestindia…
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "Good https://t.co/kzO9OGBYVT" are :
# The hashtags in "RT @TheBlancosLive: 🚨 After his brilliant performance today, Jude Bellingham cost €10M more. @jigochoa #WorldCup2022 🏴󠁧󠁢󠁥󠁮󠁧󠁿⭐️" are :
# #WorldCup2022
# The hashtags in "Make Love Not Law @fifacom_de @fifaworldcup_de #WM2022 #Lovesolutions #Quatar2022 #WorldCup2022" are :
# #WM2022
# #Lovesolutions
# #Quatar2022
# #WorldCup2022
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "#gmb These problems with the ticketing app at the #WorldCup2022 prior to #ENGIRN match is an example of why I insist on good old-fashioned proper tickets - if a venue can't provide me with those (or at least let me print-off from an email at home) then I won't go to their event." are :
# #gmb
# #WorldCup2022
# #ENGIRN
# The hashtags in "RT @TheAptosLeague: 📢THE AIRDROP HAS ARRIVED!
# Join to share the $5,000 prize pool
#
# ✅ RT/❤️ &amp; tag 3 frens
# ✅ Complete all tasks: https://t.co…" are :
# The hashtags in "Stay true to your values - they are your USPs.
#
# #alexscott #worldcup2022 #onelove https://t.co/PzBtMlJV6i" are :
# #alexscott
# #worldcup2022
# #onelove
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "RT @TheBlancosLive: 🚨 According to @franceinfo, FIFA have asked referees to apply new guidelines to maximize effective playing time. This i…" are :
# The hashtags in "Dressed appropriately for an ordinary day at the office… 🇹🇳-🇩🇰 #WorldCup2022 🏳️‍🌈! https://t.co/2pAFOtXGVm" are :
# #WorldCup2022
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/KyTDUyMjkw" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @INSIGHTUK2: "Football as a profession is Haram"
#
# Islamic preacher, Zakir Naik, who inspired some youths to join ISIS also said that #fo…" are :
# #fo…
# The hashtags in "🚨At the #WorldCup2022 games yesterday was more or less 1 hour of added time. What do you think about this rule?👇 #WorldcupQatar2022" are :
# #WorldCup2022
# #WorldcupQatar2022
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "Quite brilliant &amp; interesting project at its early stage. Its community is fast growing. My all out support goes to this project.
# @SuidenC
# @Sujan339
# @AmarShanti2 https://t.co/tItV3z4Xx1" are :
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @feedpayhq: Predict the correct score and stand a chance to win 5 Scrims (5$)
#
# NB: make sure you are following @feedpayhq
#
# #WorldCup2022…" are :
# #WorldCup2022…
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/N5xWS4GScx" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "Lambert Dickens #WorldCup2022 Ella Foster May Betty #搞钱 Christine Toby #杜兰特  https://t.co/tDK8nofdWa" are :
# #WorldCup2022
# #搞钱
# #杜兰特
# The hashtags in "#亚博体育 #WorldCup2022 #百家乐 Poppy Symons Benjamin Richards Gail Sassoon Nelson Wilcox Simon Cronin Ethel Patrick Bob Zechariah https://t.co/nKHrG69n6X" are :
# #亚博体育
# #WorldCup2022
# #百家乐
# The hashtags in "@binary_x @SecondLiveReal Quite brilliant &amp; interesting project at its early stage. Its community is fast growing. My all out support goes to this project.
# @SuidenC
# @Sujan339
# @AmarShanti2" are :
# The hashtags in "RT @TarekFatah: #Qatar welcomes #India's Wanted radical Islamist jihadi preacher Dr #ZakirNaik at the #FIFA #WorldCup2022, taking advantage…" are :
# #Qatar
# #India's
# #ZakirNaik
# #FIFA
# #WorldCup2022,
# The hashtags in "RT @Helia_m00n: Thanks @10KWorldCup @Johnsonweb3eth Airdrop❤️‍🔥
# I’ll give it to the community! Anyone want Brazil?⚽️
#
# To enter:
# 1. Follow…" are :
# The hashtags in "Jeff Nixon #WorldCup2022 Alexander Maxwell Phyllis Waters #DOGE Natividad Dickey #篮球  https://t.co/zi1VPfgzQm" are :
# #WorldCup2022
# #DOGE
# #篮球
# The hashtags in "RT @canarypunkNFT: The next Guess Score Quiz.
# Germany🇩🇪 vs Japan🇯🇵 match
# Please guess in the comments.
#
# Good Luck ⚽👍
# GIVEAWAY : Voucher Dis…" are :
# The hashtags in "$10,000 world cup event is now live on TimeSocial. Signup now and claim your cash now. It's just that easy and people are making tons of money. Signup now for a $45 bonus! https://t.co/fogSWst6pP #worldcup2022 #FIFAWorldCup #Qatar2022 #messi #cristiano" are :
# #worldcup2022
# #FIFAWorldCup
# #Qatar2022
# #messi
# #cristiano
# The hashtags in "RT @SecondLiveReal: ⚽️ #SecondLive &amp; @BNBCHAIN #WorldCup2022 Online Campaign starts!
#
# 🤑We have prepared four activities: Predict Matches, F…" are :
# #SecondLive
# #WorldCup2022
# The hashtags in "RT @SecondLiveReal: ⚽️ #SecondLive &amp; @BNBCHAIN #WorldCup2022 Online Campaign starts!
#
# 🤑We have prepared four activities: Predict Matches, F…" are :
# #SecondLive
# #WorldCup2022
# The hashtags in "RT @OnlinePalEng: "It's Palestine..."
#
# Lebanese fans refuse to be interviewed by an Israeli TV reporter after he said that he is from 'Isra…" are :
# The hashtags in "#时时彩 #WorldCup2022 #百家乐 Owen Joseph Wright Cowper Dempsey Clark(e) Porter Ellis Patrick Quiller Sally Kennedy Jack Aled(k) https://t.co/zArpRPQMoa" are :
# #时时彩
# #WorldCup2022
# #百家乐
# The hashtags in "@Shiba_QatarWC #ETH Vs #BNB
#
# Who wins?
#
# Investors decide!
# Much awaited Presale- 22nd Nov, 7pm UTC on GemPad AND PinkSale 🔥
#
# https://t.co/IcOy4sH7i8
#
# https://t.co/naD7PTI30T
#
# Come and join in the community and share your Presale memes!
# https://t.co/3Rc9w98pfV
# https://t.co/iWb7T6bOLk" are :
# #ETH
# #BNB
# The hashtags in "RT @ThomasHitz: Infantino has even managed to force the teams not to wear the #OneLove armband. How pathetic?! How about 🌈 laces 🤔? #WorldC…" are :
# #OneLove
# #WorldC…
# The hashtags in "RT @RoadQatar_WC: ☁️WELCOME TO THE ROADQATAR - AIRDROP CAMPAIGN☁️
#
# ⚽️Let's accompany ROADQATAR in the real “Road to Qatar" of WORLD CUP 202…" are :
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "RT @OnlinePalEng: Arab fans at the #WorldCup2022 say no to interviews with Israeli channels. https://t.co/x6MR5qKtZD" are :
# #WorldCup2022
# The hashtags in "RT @gambabit: $50 #WorldCup Giveaway🕊️
#
# To Enter :
# ⚽️ Like + RT
# ⚽️ Guess the score of #Argentina vs #SaudiArabia
# ⚽️ Follow Us
#
# 1 Lucky Win…" are :
# #WorldCup
# #Argentina
# #SaudiArabia
# The hashtags in "RT @AnonOpsSE: Not sure who this woman is, but she has definitely more balls then any of the football player.
#
# Bravo!
#
# #WorldCup2022 #Boyco…" are :
# #WorldCup2022
# #Boyco…
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @Un_mi2471: Join #HealthyYogaLifeStyle with #GurudevSiyagSiddhayoga. #Mentalhealth @SumanSri08
# #depression #ASMR @SGDsks
# #autism #Health…" are :
# #HealthyYogaLifeStyle
# #GurudevSiyagSiddhayoga.
# #Mentalhealth
# #depression
# #ASMR
# #autism
# #Health…
# The hashtags in "RT @FahadAlkubaisi: I can’t express my gratitude and happiness for my participation in the biggest event of all times the World Cup in my c…" are :
# The hashtags in "@canarypunkNFT i guess is draw 0:0" are :
# The hashtags in "@mohanstatsman What I read was ,220 billion$ is inclusive of infrastructure development till 2030 across Qatar to invite business," are :
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/5wWqomeVOS" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @BitMart_Futures: Are you getting ready? The #WorldCup2022 is kicking off! Drop your Champion prediction and win up to 100X Futures Fees…" are :
# #WorldCup2022
# The hashtags in "Jo Dewar #UNI Delia O'Connor York Connie #皇马 Vicky Betsy #WorldCup2022  https://t.co/aZh6SBANCh" are :
# #UNI
# #皇马
# #WorldCup2022
# The hashtags in "RT @Un_mi2471: Join #HealthyYogaLifeStyle with #GurudevSiyagSiddhayoga. #Mentalhealth @SumanSri08
# #depression #ASMR @SGDsks
# #autism #Health…" are :
# #HealthyYogaLifeStyle
# #GurudevSiyagSiddhayoga.
# #Mentalhealth
# #depression
# #ASMR
# #autism
# #Health…
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @TheShibLord1: Who do you think will win #WorldCup2022 ??
#
# Like, Rt &amp; Comment your team below and i will choose 2 people to win $100 eac…" are :
# #WorldCup2022
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "RT @MarkBareta: Important message to everyone on the ground. Let it not be said it was not told. God bless Ambazonia @FIFAcom #FIFAWorldCup…" are :
# #FIFAWorldCup…
# ...
# The hashtags in "RT @SecondLiveReal: ⚽️ #SecondLive &amp; @BNBCHAIN #WorldCup2022 Online Campaign is still ongoing!
#
# 💰Come &amp; join the Treasure Hunt in World Cup…" are :
# #SecondLive
# #WorldCup2022
# The hashtags in "@IOTASoccerTeam @iota @fireflywallet @DigiMine_ Fixx argentina will win
#
# smr1qppep92vgzu6sf5vfy7p64qshhjhcwkthv4j42sxfrruavh3954hqcp5v6f" are :
# The hashtags in "RT @Unimoni_India: 𝐏𝐫𝐞𝐝𝐢𝐜𝐭 𝐚𝐧𝐝 𝐰𝐢𝐧 𝐓𝐨𝐝𝐚𝐲'𝐬 𝐅𝐢𝐟𝐚 𝐖𝐨𝐫𝐥𝐝 𝐂𝐮𝐩 𝐌𝐚𝐭𝐜𝐡. 𝗠𝗲𝘅𝗶𝗰𝗼 𝘃𝘀 𝗣𝗼𝗹𝗮𝗻𝗱
# #contestalert #contest #contestalerindia #contestindia #w…" are :
# #contestalert
# #contest
# #contestalerindia
# #contestindia
# #w…
# The hashtags in "Which is the busiest port in the world?
# #logistics #oceancargo #DB cooper #FunFact #worldtrade #WorldCup2022" are :
# #logistics
# #oceancargo
# #DB
# #FunFact
# #worldtrade
# #WorldCup2022
# The hashtags in "RT @ChinaDaily: Highlights of the World Cup match between England and Iran #WorldCup2022 https://t.co/Ie9AV7lIzs" are :
# #WorldCup2022
# The hashtags in "RT @hosseinbastani: After Piranshahr, it is #Javanrud's turn. After Javanrud, it will be the turn of other cities. When the world is busy w…" are :
# #Javanrud's
# The hashtags in "@CNN @1500tasvir The Islamic Regime in Iran is massacring people in #Mahabad &amp; #Javanrood, hoping that the world is involved in #WorldCup2022 and ignoring the massacre.
# The I.R. is doing everything it has done in Syria (from creating ISIS to mass killing) to test the world's reaction.
# Do REACT!" are :
# #Mahabad
# #Javanrood,
# #WorldCup2022
# The hashtags in "Ansel Jonathan #WorldCup2022 Hogan Timothy Ina Vogt #Taiwan Jeffrey Douglas(s) #Aptos  https://t.co/WL9ZEEXmUT" are :
# #WorldCup2022
# #Taiwan
# #Aptos
# The hashtags in "@FIFAWorldCup
# The whole set-up is awkward! How on earth can you let more spectators in than the capacity allows - big security risk 😱 or similar to the latest election results in and around Russia! #QatarWorldCup2022
# #WorldCup2022
# https://t.co/eEWEkIjwC8" are :
# #QatarWorldCup2022
# #WorldCup2022
# The hashtags in "RT @StefSimanowitz: This is what courage looks like
#
# The Iranian football team refuses to sing the national anthem on biggest stage in the…" are :
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @IOTASoccerTeam: Drop SMR address for a chance to win free IOTASoccerTeam (IST) token airdrop!!!🔥
# Predict the result of Argentina vs Sau…" are :
# The hashtags in "@oilysailor Better value for money for TV companies. If you can get an extra e0 mins, that's a while programme..." are :
# The hashtags in "RT @ketrindelvina: My favorite moment with Ronaldo🥰
# Ronaldo Vs Blackburn Rovers
#
# #RonaldoOnBinance
# #WorldCup2022
# #Ronaldo https://t.co/Ms…" are :
# #RonaldoOnBinance
# #WorldCup2022
# #Ronaldo
# The hashtags in "Benjamin Richards #亚博体育 #WorldCup2022 #百家乐 Poppy Symons Gail Sassoon Nelson Wilcox Simon Cronin Ethel Patrick Bob Zechariah https://t.co/97GasAsxn1" are :
# #亚博体育
# #WorldCup2022
# #百家乐
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @MechcraftWorld: 📢 Nov 20 #WorldcupQatar2022 start!!!
#
# Let's have fun and Join our DC to complete the task🎁https://t.co/t2xwDChR5e
# ----…" are :
# #WorldcupQatar2022
# The hashtags in "RT @InesKostic: These players are risking their lives by speaking out against what's happening in #Iran.👇🏽
#
# But other teams, like the Dutch…" are :
# #Iran.👇🏽
# The hashtags in "World Cup Betting Match Stats For Today’s Games: Back Our 7/1 Acca
# #WorldCup #WorldCup2022
# https://t.co/FCcvb0l2Cz https://t.co/UfLRfXXJYy" are :
# #WorldCup
# #WorldCup2022
# The hashtags in "RT @TechTreesSDG: As of 2020, the UN estimates the planet is losing over 7,000,000 hectares per year to deforestation. Between 1990-2015, t…" are :
# The hashtags in "Isalamic Republic and IRGC have sent armed troops to #Kurdistan, #Mahabad, #JavanRood, #Kermanshah, #Piranshahr and are using Heavy weapons against unarmed civilians to silence their voice. Numbers have been killed and injured.
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022 https://t.co/60EWph8uua" are :
# #Kurdistan,
# #Mahabad,
# #JavanRood,
# #Kermanshah,
# #Piranshahr
# #WorldCup
# #WorldCup2022
# #FIFAWorldCup2022
# The hashtags in "Saudi Arabia beheads 12 people with swords in 10 days #WorldCup2022 #ARG #KSA https://t.co/yhMzvEcFss" are :
# #WorldCup2022
# #ARG
# #KSA
# The hashtags in "RT @TopGoal_NFT: Enjoy #WorldCup2022 with TopGoal
# Predict Match Results, Split Jackpot
#
# 🎲Predict Winning team, draw 2 with 50TMT
# 🎲Predict…" are :
# #WorldCup2022
# The hashtags in "RT @BitKeepOS: ⚽️ #BitKeep FootBall Carnival Main Event is coming⚽️
#
# 🥳 Trading activity &amp; Community quiz 🥳
#
# 📅Nov 21 - Dec 20
# ✅Join our TG &amp;…" are :
# #BitKeep
# The hashtags in "RT @BitKeepOS: ⚽️ #BitKeep FootBall Carnival Main Event is coming⚽️
#
# 🥳 Trading activity &amp; Community quiz 🥳
#
# 📅Nov 21 - Dec 20
# ✅Join our TG &amp;…" are :
# #BitKeep
# The hashtags in "#It's really an Amazing project. Don't miss it. It's gonna be huge success in future. @VinsentRick @akashperis @EianGomes2 @JonyGomes17 @PiashRozario https://t.co/iBUa7JRtG3" are :
# #It's
# The hashtags in "RT @MechcraftWorld: 📢 Nov 20 #WorldcupQatar2022 start!!!
#
# Let's have fun and Join our DC to complete the task🎁https://t.co/t2xwDChR5e
# ----…" are :
# #WorldcupQatar2022
# The hashtags in "RT @hosseinbastani: After Piranshahr, it is #Javanrud's turn. After Javanrud, it will be the turn of other cities. When the world is busy w…" are :
# #Javanrud's
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @naijaloveinfo: Results of #WorldCup2022 matches played so far:
# #Ecuador 2-0 #Qatar
# #England 6-2 #Iran
# #Netherlands 2-0 #Senegal
# #Wal…" are :
# #WorldCup2022
# #Ecuador
# #Qatar
# #England
# #Iran
# #Netherlands
# #Senegal
# #Wal…
# The hashtags in "RT @MechcraftWorld: 🔥Exclusive MechCraft Collab NFT Reveiled🔥
#
# Who's ready for this Web3 #FIFAWorldCupQatar2022?
#
# 5⃣5⃣collectible World Cup…" are :
# #FIFAWorldCupQatar2022?
# The hashtags in "RT @gambabit: $50 #WorldCup Giveaway🕊️
#
# To Enter :
# ⚽️ Like + RT
# ⚽️ Guess the score of #Argentina vs #SaudiArabia
# ⚽️ Follow Us
#
# 1 Lucky Win…" are :
# #WorldCup
# #Argentina
# #SaudiArabia
#
# Rules:
# 1. Follow @BirbDefi
# 2. Like/RT
# 3…" are :
# #WorldCup2022!⚽️🥳
# The hashtags in "If you want today’s #bet leave a comment. #footballWorldCup2022 #footballbetting #bettingpicks" are :
# #bet
# #footballWorldCup2022
# #footballbetting
# #bettingpicks
# The hashtags in "RT @SGEM_OFFICIAL: #WorldCup2022
#
# ( UTC ) 10:00 AM
#
# Argentina ⚔️ Saudi Arabia
#
# Predict the score👇
#
# The winner will be announced in the com…" are :
# #WorldCup2022
# The hashtags in "RT @IOTASoccerTeam: Drop SMR address for a chance to win free IOTASoccerTeam (IST) token airdrop!!!🔥
# Predict the result of Argentina vs Sau…" are :
# The hashtags in "RT @TomWhiteTips: Double !!!!!
# It's "Messi" time in the morning !!!!!
# #WorldCup2022 #QatarWorldCup2022 #Qatar2022 https://t.co/2Dzn2Qmcgd" are :
# #WorldCup2022
# #QatarWorldCup2022
# #Qatar2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "World Cup Outright Betting: Back England at 17/2 After Iran Win
# #WorldCup2022 #WorldCup @EnglandFootball
# https://t.co/3Z8frVBw3J" are :
# #WorldCup2022
# #WorldCup
# The hashtags in "RT @Helia_m00n: Thanks @10KWorldCup @Johnsonweb3eth Airdrop❤️‍🔥
# I’ll give it to the community! Anyone want Brazil?⚽️
#
# To enter:
# 1. Follow…" are :
# The hashtags in "RT @twitkalk: @DFB_Team @DFB Today I feel #Quatar2022
# Today I feel moneysexual and morally disabled
# Today I like a bald spineless ex-redhe…" are :
# #Quatar2022
# The hashtags in "RT @RoseonWorld: EVENT 2: WINNERS OF GROUP PREDICTION
#
# ⚽️  Reply to our telegram post (https://t.co/npO2Sbs7z1)  the top 1 of each group i…" are :
# The hashtags in "RT @gnuseibeh: Qatar World Cup so far:
#
# 1. Invited extremist preacher banned from Britain to preach to Muslim fans 🇬🇧
# 2. Banned Jewish wor…" are :
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "Yes it is true. You can get a refund (or half refund) for your EGC Country Card purchase depending on the results of your country during #WorldCup2022 .
#
# Today's matches:
# 11AM 🇦🇷 v 🇸🇦
# 2 PM 🇩🇰 v 🇹🇳
# 5 PM🇲🇽 v 🇵🇱
# 8 PM🇫🇷 v 🇦🇺
#
# 88% chance when you buy 🇸🇦
# 79% chance when you buy 🇦🇺 https://t.co/Mta28n8DxF" are :
# #WorldCup2022
# The hashtags in "RT @MechcraftWorld: Don't just sit there and watch the @FIFAWorldCup🕺🏿💃🏻!
#
# Join MechCraft DC to find out more: https://t.co/t2xwDChjfG
# ----…" are :
# The hashtags in "RT @gambabit: $50 #WorldCup Giveaway🕊️
#
# To Enter :
# ⚽️ Like + RT
# ⚽️ Guess the score of #Argentina vs #SaudiArabia
# ⚽️ Follow Us
#
# 1 Lucky Win…" are :
# #WorldCup
# #Argentina
# #SaudiArabia
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "Cathy Ingersoll #真人首存 Lester Abraham Taylor Sherwood #WorldCup2022 Tracy Howard #足球  https://t.co/BANmewoS3T" are :
# #真人首存
# #WorldCup2022
# #足球
# The hashtags in "@romi_chase Now I am confused whether to encourage Saudi Arabia or encourage Poland because of you" are :
# The hashtags in "RT @gambabit: $50 #WorldCup Giveaway🕊️
#
# To Enter :
# ⚽️ Like + RT
# ⚽️ Guess the score of #Argentina vs #SaudiArabia
# ⚽️ Follow Us
#
# 1 Lucky Win…" are :
# #WorldCup
# #Argentina
# #SaudiArabia
# The hashtags in "RT @FootEarn: 💥 "FOOTEARN'S WORLDCUP EVENT" STARTS NOW‼️
#
# ➡️FootEarn's World Cup event is new operation model, extremely attractive, play i…" are :
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @Shiba_QatarWC: 𝟑 𝐝𝐚𝐲𝐬 𝐥𝐞𝐟𝐭 ⚽️🏆
#
# The moment is coming 💥
# #ShibaQatarWC #SQW #SQWtoken #BSC #WorldCup2022 #tokenization https://t.co/sXz9f…" are :
# #ShibaQatarWC
# #SQW
# #SQWtoken
# #BSC
# #WorldCup2022
# #tokenization
# The hashtags in "RT @JustStop_Oil: #WorldCup fact – there are more people in prison for taking a stand against new oil and gas licences in the UK than there…" are :
# #WorldCup
# The hashtags in "RT @binary_x: ❓Which team will lift the trophy? 🏆
#
# ⚽Join #WorldCup2022 Result Prediction Campaign!
#
# 🏆Predict matches and Share $20000 Priz…" are :
# #WorldCup2022
# The hashtags in "RT @IranNewsUpdate1: #IranRevolution2022
# Despite the mullahs' deceitful tricks, such as resorting to #WorldCup2022 to divert attention from…" are :
# #IranRevolution2022
# #WorldCup2022
# The hashtags in "RT @TaylorMaydeuk: Looking for gift ideas ?
#
# I have these personalised handmade crates available to order ♡
#
# Great for all occasions ♡
#
# htt…" are :
# C:\apps\spark-3.0.0-bin-hadoop2.7\python\pyspark\sql\pandas\conversion.py:327: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# root
#  |-- tweet_id: string (nullable = true)
#  |-- ArrivalTimestamp: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- tweet_text: string (nullable = true)
#  |-- word_count_on_text: long (nullable = true)
#  |-- hashtags_from_text: string (nullable = true)
#  |-- hashtags_count: long (nullable = true)
#  |-- sentiment: string (nullable = true)

# %% [markdown]
# ### 3. To send Spark Dataframe to KDA for analysis

# %% [markdown]
# #### 3a. Convert Spark Dataframe into a list of dictionaries

# %%
list_of_dict = spark_df.rdd.map(lambda row: row.asDict()).collect()
count = 0

# %% [markdown]
# #### 3b. Connect and send list of dictionaries to Kinesis Data Analytics

# %%
kinesis_client = boto3.client('kinesis')
counter = 0

for r in list_of_dict:
    # Send message to Kinesis DataStream

    response = kinesis_client.put_record(
        StreamName = KINESIS_DATA_STREAM,
        Data = json.dumps(r),
        PartitionKey = str(hash(r['tweet_id']))
    )
    counter = counter + 1
    print('Message sent #' + str(counter))
    
    # If the message was not sucessfully sent print an error message
    if response['ResponseMetadata']['HTTPStatusCode'] != 200:
        print('Error!')
        print(response)
# Out:
# Message sent #1
# Message sent #2
# Message sent #3
# Message sent #4
# Message sent #5
# Message sent #6
# Message sent #7
# Message sent #8
# Message sent #9
# Message sent #10
# Message sent #11
# Message sent #12
# Message sent #13
# Message sent #14
# Message sent #15
# Message sent #16
# Message sent #17
# Message sent #18
# Message sent #19
# Message sent #20
# Message sent #21
# Message sent #22
# Message sent #23
# Message sent #24
# Message sent #25
# Message sent #26
# Message sent #27
# Message sent #28
